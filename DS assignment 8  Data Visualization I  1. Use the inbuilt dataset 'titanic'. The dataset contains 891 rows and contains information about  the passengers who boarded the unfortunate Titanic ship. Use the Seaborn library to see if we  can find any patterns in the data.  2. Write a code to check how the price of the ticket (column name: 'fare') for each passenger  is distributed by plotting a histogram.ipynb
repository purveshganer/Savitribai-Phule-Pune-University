# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
dataset = sns.load_dataset('titanic')
dataset.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(x = dataset['age'], bins = 10)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(dataset['age'], bins = 10,kde=False)
# Out:
# <Axes: xlabel='age'>

# %%
sns.jointplot(x=dataset['age'], y=dataset['fare'], kind='scatter', ax=axes[0])
sns.jointplot(x=dataset['age'], y=dataset['fare'], kind='hex', ax=axes[1])

# %%
sns.rugplot(dataset['fare'])
# Out:
# <Axes: xlabel='fare'>

# %%
sns.barplot(x=dataset['sex'],y=dataset['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x=dataset['sex'],y=dataset['age'],estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.countplot(x=dataset['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x=dataset['sex'],y=dataset['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x='sex',y='age',data=dataset,hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex',y='age',data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex',y='age',data=dataset,hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=False)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=True, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='sex', y='age', data=dataset, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for column in ['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive', 'alone']:
    dataset[column] = label_encoder.fit_transform(dataset[column])

# Calculate correlation matrix
corr_matrix = dataset.corr()
corr_matrix
# Out:
#              survived    pclass       sex       age     sibsp     parch  \
# survived     1.000000 -0.338481 -0.543351 -0.077221 -0.035322  0.081629
# pclass      -0.338481  1.000000  0.131900 -0.369226  0.083081  0.018443
# sex         -0.543351  0.131900  1.000000  0.093254 -0.114631 -0.245489
# age         -0.077221 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# sibsp       -0.035322  0.083081 -0.114631 -0.308247  1.000000  0.414838
# parch        0.081629  0.018443 -0.245489 -0.189119  0.414838  1.000000
# fare         0.257307 -0.549500 -0.182333  0.096067  0.159651  0.216225
# embarked    -0.163517  0.157112  0.104057 -0.025252  0.066654  0.038322
# class       -0.338481  1.000000  0.131900 -0.369226  0.083081  0.018443
# who          0.325753 -0.196793 -0.639773  0.378685 -0.136003 -0.055682
# adult_male  -0.557080  0.094035  0.908578  0.280328 -0.253586 -0.349943
# deck        -0.294804  0.743251  0.118282 -0.267987  0.041333 -0.031308
# embark_town -0.163517  0.157112  0.104057 -0.025252  0.066654  0.038322
# alive        1.000000 -0.338481 -0.543351 -0.077221 -0.035322  0.081629
# alone       -0.203367  0.135207  0.303646  0.198270 -0.584471 -0.583398
#
#                  fare  embarked     class       who  adult_male      deck  \
# survived     0.257307 -0.163517 -0.338481  0.325753   -0.557080 -0.294804
# pclass      -0.549500  0.157112  1.000000 -0.196793    0.094035  0.743251
# sex         -0.182333  0.104057  0.131900 -0.639773    0.908578  0.118282
# age          0.096067 -0.025252 -0.369226  0.378685    0.280328 -0.267987
# sibsp        0.159651  0.066654  0.083081 -0.136003   -0.253586  0.041333
# parch        0.216225  0.038322  0.018443 -0.055682   -0.349943 -0.031308
# fare         1.000000 -0.221226 -0.549500  0.146290   -0.182024 -0.525994
# embarked    -0.221226  1.000000  0.157112 -0.060177    0.088725  0.191735
# class       -0.549500  0.157112  1.000000 -0.196793    0.094035  0.743251
# who          0.146290 -0.060177 -0.196793  1.000000   -0.437532 -0.153766
# adult_male  -0.182024  0.088725  0.094035 -0.437532    1.000000  0.098553
# deck        -0.525994  0.191735  0.743251 -0.153766    0.098553  1.000000
# embark_town -0.221226  1.000000  0.157112 -0.060177    0.088725  0.191735
# alive        0.257307 -0.163517 -0.338481  0.325753   -0.557080 -0.294804
# alone       -0.271832  0.065610  0.135207  0.006540    0.404744  0.137515
#
#              embark_town     alive     alone
# survived       -0.163517  1.000000 -0.203367
# pclass          0.157112 -0.338481  0.135207
# sex             0.104057 -0.543351  0.303646
# age            -0.025252 -0.077221  0.198270
# sibsp           0.066654 -0.035322 -0.584471
# parch           0.038322  0.081629 -0.583398
# fare           -0.221226  0.257307 -0.271832
# embarked        1.000000 -0.163517  0.065610
# class           0.157112 -0.338481  0.135207
# who            -0.060177  0.325753  0.006540
# adult_male      0.088725 -0.557080  0.404744
# deck            0.191735 -0.294804  0.137515
# embark_town     1.000000 -0.163517  0.065610
# alive          -0.163517  1.000000 -0.203367
# alone           0.065610 -0.203367  1.000000

# %%
corr = dataset.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
corr = dataset.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
corr = dataset.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
  dataset = sns.load_dataset('titanic')
sns.histplot(dataset['fare'], kde=False, bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
